# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasCod-eng/Deep-Learning/blob/main/Deep_Learning_A_Z_Classifica%C3%A7%C3%A3o_bin%C3%A1ria_Breast_Cancer_Simples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
# previsores
X = pd.read_csv('entradas_breast.csv')
X
# Out:
#       radius_mean   texture_mean   perimeter_mean   area_mean  \
# 0           17.99          10.38           122.80      1001.0
# 1           20.57          17.77           132.90      1326.0
# 2           19.69          21.25           130.00      1203.0
# 3           11.42          20.38            77.58       386.1
# 4           20.29          14.34           135.10      1297.0
# ..            ...            ...              ...         ...
# 564         21.56          22.39           142.00      1479.0
# 565         20.13          28.25           131.20      1261.0
# 566         16.60          28.08           108.30       858.1
# 567         20.60          29.33           140.10      1265.0
# 568          7.76          24.54            47.92       181.0
#
#       smoothness_mean   compactness_mean   concavity_mean  \
# 0             0.11840            0.27760          0.30010
# 1             0.08474            0.07864          0.08690
# ...

# %%
# classe
y = pd.read_csv('saidas_breast.csv')
y
# Out:
#      0
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# ..  ..
# 564  0
# 565  0
# 566  0
# 567  0
# 568  1
#
# [569 rows x 1 columns]

# %%
import sklearn
from sklearn.model_selection import train_test_split

# %%
sklearn.__version__
# Out:
# '1.6.1'

# %%
X_treinamento, X_teste, y_treinamento, y_teste = train_test_split(X, y, test_size=0.25)

# %%
X_treinamento.shape, y_treinamento.shape
# Out:
# ((426, 30), (426, 1))

# %%
X_teste.shape,y_teste.shape
# Out:
# ((143, 30), (143, 1))

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential

# %%
rede_neural = Sequential([
    tf.keras.layers.Input(shape=(30,)),
    tf.keras.layers.Dense(units=16, activation='relu', kernel_initializer='random_uniform'),
    tf.keras.layers.Dense(units=16, activation='relu', kernel_initializer='random_uniform'),
    tf.keras.layers.Dense(units=1, activation='sigmoid'),

])

# %%
rede_neural.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                      │ (None, 16)                  │             496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 16)                  │             272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 785 (3.07 KB)
#  Trainable params: 785 (3.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
otimizador = tf.keras.optimizers.Adam(learning_rate=0.001, decay=0.0001, clipvalue=0.5)

# %%
rede_neural.compile(optimizer='adam', loss='binary_crossentropy', metrics=['binary_accuracy'])

# %%
rede_neural.fit(X_treinamento, y_treinamento, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - binary_accuracy: 0.5447 - loss: 1.1214
# Epoch 2/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 0.6416 - loss: 0.7759
# Epoch 3/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 0.7143 - loss: 0.5198
# Epoch 4/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 0.7714 - loss: 0.4507
# Epoch 5/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 0.7860 - loss: 0.4461
# Epoch 6/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 0.8385 - loss: 0.4104
# Epoch 7/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 0.8786 - loss: 0.3116
# Epoch 8/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 0.9031 - loss: 0.3061
# Epoch 9/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8888 - loss: 0.2836
# Epoch 10/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 0.8587 - loss: 0.3486
# Epoch 11/100
# ...

# %%
pessos0 = rede_neural.layers[0].get_weights()
pessos0
# Out:
# [array([[-8.04837197e-02,  6.24520145e-02, -1.95808560e-01,
#          -1.44015417e-01, -1.72234687e-03,  3.04641604e-01,
#          -2.93149650e-02,  1.20793208e-01, -4.63224836e-02,
#          -1.31468670e-02,  7.76405539e-03, -2.59006798e-01,
#          -1.81928668e-02, -2.11118504e-01,  3.95269096e-02,
#           3.84213589e-02],
#         [-2.14586258e-01, -1.32898032e-03, -1.19375251e-01,
#           4.09178361e-02,  8.87818709e-02,  8.39970857e-02,
#           1.88285522e-02,  8.13174397e-02, -4.23736684e-02,
#           6.15655743e-02,  7.21427649e-02,  1.27065733e-01,
#          -1.01594776e-02,  1.02602713e-01,  8.56559724e-02,
#           9.40161496e-02],
#         [-5.66689298e-02,  1.63493916e-01, -1.02750175e-01,
#          -2.61906028e-01, -1.12151928e-01,  3.01916301e-01,
#           3.81753482e-02,  2.28973940e-01, -4.05613035e-02,
#          -2.19676420e-01,  2.07461059e-01, -1.91867828e-01,
#          -1.15342829e-02, -1.00652322e-01,  1.16531998e-01,
# ...

# %%
len(pessos0)
# Out:
# 2

# %%
pessos0[0]
# Out:
# array([[-8.04837197e-02,  6.24520145e-02, -1.95808560e-01,
#         -1.44015417e-01, -1.72234687e-03,  3.04641604e-01,
#         -2.93149650e-02,  1.20793208e-01, -4.63224836e-02,
#         -1.31468670e-02,  7.76405539e-03, -2.59006798e-01,
#         -1.81928668e-02, -2.11118504e-01,  3.95269096e-02,
#          3.84213589e-02],
#        [-2.14586258e-01, -1.32898032e-03, -1.19375251e-01,
#          4.09178361e-02,  8.87818709e-02,  8.39970857e-02,
#          1.88285522e-02,  8.13174397e-02, -4.23736684e-02,
#          6.15655743e-02,  7.21427649e-02,  1.27065733e-01,
#         -1.01594776e-02,  1.02602713e-01,  8.56559724e-02,
#          9.40161496e-02],
#        [-5.66689298e-02,  1.63493916e-01, -1.02750175e-01,
#         -2.61906028e-01, -1.12151928e-01,  3.01916301e-01,
#          3.81753482e-02,  2.28973940e-01, -4.05613035e-02,
#         -2.19676420e-01,  2.07461059e-01, -1.91867828e-01,
#         -1.15342829e-02, -1.00652322e-01,  1.16531998e-01,
#          1.61097512e-01],
# ...

# %%
previsoes = rede_neural.predict(X_teste)
previsoes = (previsoes > 0.5)
previsoes
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# array([[ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
# ...

# %%
y_teste
# Out:
#      0
# 91   0
# 284  1
# 498  0
# 378  1
# 346  1
# ..  ..
# 299  1
# 308  1
# 243  1
# 262  0
# 351  0
#
# [143 rows x 1 columns]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
accuracy_score(y_teste, previsoes)
# Out:
# 0.8951048951048951

# %%
confusion_matrix(y_teste, previsoes)
# Out:
# array([[43,  6],
#        [ 9, 85]])

# %%
rede_neural.evaluate(X_teste, y_teste)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - binary_accuracy: 0.9090 - loss: 0.3022
# [0.39891448616981506, 0.8951048851013184]
