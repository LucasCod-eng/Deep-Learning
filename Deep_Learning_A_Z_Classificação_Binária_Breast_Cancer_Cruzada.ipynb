# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasCod-eng/Deep-Learning/blob/main/Deep_Learning_A_Z_Classifica%C3%A7%C3%A3o_Bin%C3%A1ria_Breast_Cancer_Cruzada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Learning A Z Classificação Binária - Breast Cancer Cruzada

# %%
# !pip install scikeras==0.13.0

# %%
# !pip install tensorflow==2.16.1 scikit-learn==1.5.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 589.8/589.8 MB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 38.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 21.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 21.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.1
#     Uninstalling ml-dtypes-0.4.1:
#       Successfully uninstalled ml-dtypes-0.4.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.18.0
#     Uninstalling tensorboard-2.18.0:
#       Successfully uninstalled tensorboard-2.18.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.18.0
#     Uninstalling tensorflow-2.18.0:
# ...

# %%
import pandas as pd
import tensorflow as tf
import sklearn
import scikeras

# %%
pd.__version__, tf.__version__, sklearn.__version__, scikeras.__version__
# Out:
# ('2.2.2', '2.16.1', '1.5.0', '0.13.0')

# %%
from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import cross_val_score
from tensorflow.keras.models import Sequential
from tensorflow.keras import backend as k

# %%
X = pd.read_csv('entradas_breast.csv')
y = pd.read_csv('saidas_breast.csv')

# %% [markdown]
# Artigo dropout: https://www.cs.toronto.edu/~rsalakhu/papers/srivastava14a.pdf

# %%
def criar_rede():
  k.clear_session()
  rede_neural = Sequential([
      tf.keras.layers.InputLayer(shape=(30,)),
      tf.keras.layers.Dense(units=16, activation='relu', kernel_initializer='random_uniform'),
      tf.keras.layers.Dropout(rate = 0.2),
      tf.keras.layers.Dense(units=16, activation='relu', kernel_initializer='random_uniform'),
      tf.keras.layers.Dropout(rate = 0.2),
      tf.keras.layers.Dense(units=1, activation = 'sigmoid')])
  otimizador = tf.keras.optimizers.Adam(learning_rate = 0.001, clipvalue = 0.5)
  rede_neural.compile(optimizer = otimizador, loss = 'binary_crossentropy', metrics = ['binary_accuracy'])
  return rede_neural

# %%
rede_neural = KerasClassifier(model = criar_rede, epochs = 100, batch_size = 10)

# %%
resultados = cross_val_score(estimator = rede_neural, X = X, y = y, cv = 10, scoring = 'accuracy')
# Out:
# Epoch 1/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - binary_accuracy: 0.6053 - loss: 1.3435
# Epoch 2/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.6311 - loss: 0.6940
# Epoch 3/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.6682 - loss: 0.6567
# Epoch 4/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.6457 - loss: 0.6111
# Epoch 5/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.6615 - loss: 0.6824
# Epoch 6/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.7219 - loss: 0.5741
# Epoch 7/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.7718 - loss: 0.5142
# Epoch 8/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.7694 - loss: 0.5120
# Epoch 9/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.7919 - loss: 0.6726
# Epoch 10/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.7237 - loss: 0.6516
# Epoch 11/100
# ...

# %%
# Com dropout
resultados
# Out:
# array([0.84210526, 0.84210526, 0.87719298, 0.9122807 , 0.80701754,
#        0.87719298, 0.89473684, 0.92982456, 0.73684211, 0.875     ])

# %%
# Sem dropout
resultados
# Out:
# array([0.84210526, 0.84210526, 0.87719298, 0.9122807 , 0.80701754,
#        0.87719298, 0.89473684, 0.92982456, 0.73684211, 0.875     ])

# %%
# Com dropout
resultados.mean()
# Out:
# 0.8594298245614034

# %%
# Sem dropout
resultados.mean()
# Out:
# 0.8594298245614034

# %%
# Com dropout
resultados.std()
# Out:
# 0.053144883619881615

# %%
# Sem dropout
resultados.std()
# Out:
# 0.053144883619881615
